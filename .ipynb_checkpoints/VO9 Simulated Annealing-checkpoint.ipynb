# %% [markdown]
# # VO9 Simulated Annealing

# %%
import os

import numpy as np
import pandas as pd
import random
import math

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from PIL import Image

from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# ## Extract Input Image

# %%
input_data_folder = "input_data"
df = pd.read_csv(os.path.join(input_data_folder, "SimMRimage.dat"), header=None)
len(df)
# Out:
# 84582

# %%
i_max = max(df[0].apply(lambda x: int(x[:5])))
j_max = max(df[0].apply(lambda x: int(x[5:10])))
print("i_max: %i, j_max: %i" % (i_max, j_max))
assert len(df) == i_max*j_max
# Out:
# i_max: 254, j_max: 333

# %%
pixel = df[0].apply(lambda x: int(x[10:])).values
print(max(pixel), min(pixel))
plt.title("distribution of pixel values")
plt.hist(pixel)
plt.show()
plt.close()
# Out:
# 2000 0

# %%
img = np.zeros(shape=(i_max, j_max))
for i in range(i_max):
    for j in range(j_max):
        img[i,j] = int(pixel[i*j_max+j])

img = np.transpose(img)
img_obj = Image.fromarray(img)
imshow(img_obj);

# %% [markdown]
# ## Simulated Annealing

# %%
# img = img[::3, ::3]

# %%
def get_init_states(num_classes, size, plot=False):
    x = np.random.choice([i for i in range(num_classes)], size=size)
    if(plot):
        plt.title("randomly intitalized states")
        plt.imshow(x)
        plt.show()
        plt.close()
    return x

def calc_energy(x, x_new, curr_img, i, j, i_max, j_max, neighbors, J, SIGMA, MW): 
    dE = 0
    for neigh in neighbors:
        if(x[(i+neigh[0])%i_max, (j+neigh[1])%j_max] == x_new):
            dE -= J
        if(x[(i+neigh[0])%i_max, (j+neigh[1])%j_max] == x[i,j]):
            dE += J
    dE += (curr_img - MW[x_new])**2/(2*SIGMA[x_new]**2) + np.log(SIGMA[x_new])
    dE -= (curr_img - MW[x[i,j]])**2/(2*SIGMA[x[i,j]]**2) + np.log(SIGMA[x[i,j]])
    return dE

def sweep(x, neighbors, t, J, SIGMA, MW):
    i_max = x.shape[0]
    j_max = x.shape[1]

    for _ in range(x.size):
        neigh_i, neigh_j = random.choice(neighbors)
        i = random.randint(0, i_max-1)
        j = random.randint(0, j_max-1)

        # get neighboring x
#         x_new = x[(i+neigh_i)%i_max, (j+neigh_j)%j_max]
        
        # get local x
        i_new = random.randint(0, i_max-1)
        j_new = random.randint(0, j_max-1)
        x_new = x[i_new, j_new]

        dE = calc_energy(x, x_new, img[i, j], i, j, i_max, j_max, neighbors, J, SIGMA, MW)
        
        if(dE/t > 20):
            r = 0
        elif(dE/t < 0.05):
            r = 1
        else:
            r = np.exp(-dE/t)
        
        if(random.random() < min(1, r)):
            x[i,j] = x_new

    return x

# %%
MW = [30,426,602,1223,167]
SIGMA = [30,59,102,307,69]
neighbors = [(1,0), (-1,0), (0,1), (0,-1)]

start_t = 100#1500
end_t = 1
num_classes = 5
lambd = 1.1
J = -1

x = get_init_states(num_classes, img.shape, plot=True)

t_test = start_t
itr = 0
while(t_test > end_t):
    t_test /= lambd
    itr += 1
print("planned iterations: %i" % itr)

t = start_t
for k in tqdm(range(itr)):
    print("itr: %i, t: %f" % (k, t))
    
    x = sweep(x, neighbors, t, J, SIGMA, MW)
    if(k%(int(itr/5))==0):
        plt.imshow(x)
        plt.show()
        plt.close()

    t /= lambd
    
    
plt.title("target")
plt.imshow(img)
plt.show()
plt.close()
# Out:
# planned iterations: 49
# HBox(children=(IntProgress(value=0, max=49), HTML(value='')))
# itr: 0, t: 100.000000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-0303de7e139c> in <module>()
#      22     print("itr: %i, t: %f" % (k, t))
#      23
# ---> 24     x = sweep(x, neighbors, t, J, SIGMA, MW)
#      25     if(k%(int(itr/5))==0):
#      26         plt.imshow(x)
#
# <ipython-input-32-f91d3f452041> in sweep(x, neighbors, t, J, SIGMA, MW)
#      23     j_max = x.shape[1]
#      24
# ---> 25     for _ in range(int(x.size[0]*x.size[1])):
#      26         neigh_i, neigh_j = random.choice(neighbors)
#      27         i = random.randint(0, i_max-1)
#
# TypeError: 'int' object is not subscriptable
